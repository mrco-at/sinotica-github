# %% [markdown]
# ### chamando as bibliotecas

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
from metpy.plots import add_metpy_logo, USCOUNTIES
# %matplotlib inline
import metpy.calc as mpcalc
from metpy.units import units
import numpy as np
import xarray as xr
import pandas as pd

# %% [markdown]
# ### abrindo os dados e parse

# %%
ds = xr.open_dataset('era5-temp-850-150722.nc').metpy.parse_cf()
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 361, time: 1)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 0.0 -0.25 -0.5 -0.75 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2022-07-15T15:00:00
#     metpy_crs  object Projection: latitude_longitude
# Data variables:
#     z          (time, latitude, longitude) float32 ...
#     t          (time, latitude, longitude) float32 ...
#     u          (time, latitude, longitude) float32 ...
#     v          (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-10-31 14:26:22 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %% [markdown]
# Pegue dados e suavize usando um filtro de nove pontos aplicado 50 vezes para capturar o sinal sinótico

# %%
dsu=ds['u']
dsv=ds['v']
dsz=ds['z']
dst=ds['t']

# %%
dst
# Out:
# <xarray.DataArray 't' (time: 1, latitude: 361, longitude: 1440)>
# array([[[290.52057, 290.57153, ..., 290.5261 , 290.46402],
#         [290.58484, 290.5383 , ..., 290.5671 , 290.56934],
#         ...,
#         [231.31473, 231.31363, ..., 231.3225 , 231.31917],
#         [231.74486, 231.74486, ..., 231.74486, 231.74486]]], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 0.0 -0.25 -0.5 -0.75 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2022-07-15T15:00:00
#     metpy_crs  object Projection: latitude_longitude
# Attributes:
#     units:          K
#     long_name:      Temperature
#     standard_name:  air_temperature

# %%
dst2=np.array(dst)

# %% [markdown]
# dst2

# %%
dst2.shape
# Out:
# (1, 361, 1440)

# %%
dst3=np.squeeze(dst2).shape

# %%
dst3=dst2[0,:,:]
print(dst3.shape)
# Out:
# (361, 1440)

# %%
np.info(dst2)
# Out:
# class:  ndarray
# shape:  (1, 361, 1440)
# strides:  (2079360, 5760, 4)
# itemsize:  4
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0xe945d00
# byteorder:  little
# byteswap:  False
# type: float32

# %%
# Compute grid spacings for data
dx, dy = mpcalc.lat_lon_grid_deltas(ds['longitude'], ds['latitude'])



# Compute the divergence of the Q-vectors calculated above
#q_div = -2*mpcalc.divergence(uqvect, vqvect, dx, dy, dim_order='yx')

# %%
# Compute the Q-vector components
qvector = mpcalc.q_vector(dsu*units('m/s'),dsv*units('m/s'),dst*units('kelvin'),850*units('hPa'),11.1*units.km,11.1*units.km)

# %%
qvector
# Out:
# (<xarray.DataArray (time: 1, latitude: 361, longitude: 1440)>
#  <Quantity([[[-3.57235577e-13  8.88606856e-14 -6.36689830e-13 ...  2.27293059e-13
#     -3.35431772e-13 -1.29704026e-12]
#    [ 1.00780462e-13  1.70101873e-14 -1.21063961e-14 ... -9.78520360e-14
#      5.25234003e-14 -1.51643821e-13]
#    [-1.32501626e-14  3.24965530e-14  1.76008703e-13 ... -3.17769124e-13
#      5.13819220e-14  3.06851254e-13]
#    ...
#    [ 5.07528696e-13  5.50455059e-13  5.50353313e-13 ...  5.49534530e-13
#      5.72885458e-13  5.73692483e-13]
#    [ 7.65158387e-14  7.33197455e-14  7.08042404e-14 ...  8.10253247e-14
#      8.02667874e-14  7.83137815e-14]
#    [-1.97119654e-30 -0.00000000e+00 -0.00000000e+00 ... -0.00000000e+00
#     -0.00000000e+00  3.91719574e-30]]], 'meter ** 2 / kilogram / second')>
#  Coordinates:
#    * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#    * latitude   (latitude) float32 0.0 -0.25 -0.5 -0.75 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2022-07-15T15:00:00
#      metpy_crs  object Projection: latitude_longitude,
#  <xarray.DataArray (time: 1, latitude: 361, longitude: 1440)>
#  <Quantity([[[ 5.24422159e-13  7.47752597e-14  6.42487676e-13 ...  1.81748783e-13
#     -6.93915564e-13 -3.59265296e-13]
#    [-6.96905165e-13 -2.04649074e-13 -4.04827931e-14 ...  6.14466823e-13
#      1.21592503e-13 -5.58119308e-15]
#    [-4.09519948e-13 -9.38494411e-14 -2.54981333e-13 ...  3.09976929e-13
#      3.15376720e-14 -9.20958606e-14]
#    ...
#    [-1.14816532e-11 -1.14590954e-11 -1.14523064e-11 ... -1.14713140e-11
#     -1.15007489e-11 -1.15070438e-11]
#    [-2.40709212e-12 -2.64813624e-12 -2.71097967e-12 ... -2.93664051e-12
#     -2.85137315e-12 -2.72846514e-12]
#    [ 4.77047599e-11  4.87900825e-11  5.02193338e-11 ...  4.36806653e-11
#      4.50382384e-11  4.63272524e-11]]], 'meter ** 2 / kilogram / second')>
#  Coordinates:
#    * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#    * latitude   (latitude) float32 0.0 -0.25 -0.5 -0.75 ... -89.5 -89.75 -90.0
#    * time       (time) datetime64[ns] 2022-07-15T15:00:00
#      metpy_crs  object Projection: latitude_longitude)

# %%
m='meter ** 2 / kilogram / second'

# %%
q_vector_u=qvector[0]
q_vector_v=qvector[1]

# %%
#rs=ccrs.LambertConformal(central_longitude=-53,central_latitude=45)
crs=ccrs.LambertCylindrical()
data_crs=ccrs.LambertCylindrical()

# %%
lons, lats = np.meshgrid(ds['longitude'], ds['latitude'])

# %%
lons
# Out:
# array([[-180.  , -179.75, -179.5 , ...,  179.25,  179.5 ,  179.75],
#        [-180.  , -179.75, -179.5 , ...,  179.25,  179.5 ,  179.75],
#        [-180.  , -179.75, -179.5 , ...,  179.25,  179.5 ,  179.75],
#        ...,
#        [-180.  , -179.75, -179.5 , ...,  179.25,  179.5 ,  179.75],
#        [-180.  , -179.75, -179.5 , ...,  179.25,  179.5 ,  179.75],
#        [-180.  , -179.75, -179.5 , ...,  179.25,  179.5 ,  179.75]],
#       dtype=float32)

# %%
plt.figure(figsize=(12,9))
ax = plt.axes(projection=ccrs.LambertCylindrical())
ax.set_extent([-90,-30,10,-89])
ax.coastlines(resolution='110m')
ax.add_feature(cfeature.BORDERS)
c =  ax.contourf(lons,lats,dst3,cmap='coolwarm')
ax.quiver(dsu,dsv,q_vector_u,q_vector_v)
ax.clabel(c,inline=True,fontsize=10)
plt.colorbar(c,shrink=0.6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5740/1327123734.py in <module>
#       5 ax.add_feature(cfeature.BORDERS)
#       6 c =  ax.contourf(lons,lats,dst3,cmap='coolwarm')
# ----> 7 ax.quiver(dsu,dsv,q_vector_u,q_vector_v)
#       8 ax.clabel(c,inline=True,fontsize=10)
#       9 plt.colorbar(c,shrink=0.6)
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py in wrapper(self, *args, **kwargs)
#     316
#     317         kwargs['transform'] = transform
# --> 318         return func(self, *args, **kwargs)
#     319     return wrapper
#     320
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py in quiver(self, x, y, u, v, *args, **kwargs)
#    2092                 x, y = np.meshgrid(x, y)
#    2093             u, v = self.projection.transform_vectors(t, x, y, u, v)
# -> 2094         return super().quiver(x, y, u, v, *args, **kwargs)
#    2095
#    2096     @_add_transform
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/matplotlib/axes/_axes.py in quiver(self, *args, **kwargs)
#    4979         # Make sure units are handled for x and y values
#    4980         args = self._quiver_units(args, kwargs)
# -> 4981         q = mquiver.Quiver(self, *args, **kwargs)
#    4982         self.add_collection(q, autolim=True)
#    4983         self._request_autoscale_view()
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/matplotlib/quiver.py in __init__(self, ax, scale, headwidth, headlength, headaxislength, minshaft, minlength, units, scale_units, angles, width, color, pivot, *args, **kw)
#     463         """
#     464         self._axes = ax  # The attr actually set by the Artist.axes property.
# --> 465         X, Y, U, V, C = _parse_args(*args, caller_name='quiver()')
#     466         self.X = X
#     467         self.Y = Y
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/matplotlib/quiver.py in _parse_args(caller_name, *args)
#     408                         f'{len_args} were given')
#     409
# --> 410     nr, nc = (1, U.shape[0]) if U.ndim == 1 else U.shape
#     411
#     412     if X is not None:
#
# ValueError: too many values to unpack (expected 2)

# %%
fig=plt.figure(figsize=(12,9))
add_metpy_logo(fig,20,20,size='small')

ax=fig.add_subplot(1,1,1,projection=crs)
#x.set_extent(crs=data_crs)
#.add_feature(cfeature.STATES, linewidth=0.75)
#x.add_feature(USCOUNTIES.with_scale('5m'),linewidth=0.25)

         
c1=ax.contourf(dx,dy,dst,transform=data_crs,colors='k',linewidths=1)

ax.quiver(dx,dy,qvector)
ax.clabel(c1, inline=True,fontsize=10)
plt.colobar(c,shrink=0.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5740/4168247905.py in <module>
#       7 #x.add_feature(USCOUNTIES.with_scale('5m'),linewidth=0.25)
#       8
# ----> 9 c =  ax.contourf(dx,dy,dst,transform=data_crs,cmap='coolwarm')
#      10
#      11 c1=ax.contourf(dx,dy,dst,transform=data_crs,colors='k',linewidths=1)
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py in wrapper(self, *args, **kwargs)
#     316
#     317         kwargs['transform'] = transform
# --> 318         return func(self, *args, **kwargs)
#     319     return wrapper
#     320
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py in wrapper(self, *args, **kwargs)
#     360             # Use the new points as the input arguments
#     361             args = (x, y, z) + args[3:]
# --> 362         return func(self, *args, **kwargs)
#     363     return wrapper
#     364
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py in contourf(self, *args, **kwargs)
#    1660                         sub_trans.force_path_ccw = True
#    1661
# -> 1662         result = super().contourf(*args, **kwargs)
#    1663
#    1664         # We need to compute the dataLim correctly for contours.
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6311         """
#    6312         kwargs['filled'] = True
# -> 6313         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6314         self._request_autoscale_view()
#    6315         return contours
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     810         self._transform = transform
#     811
# --> 812         kwargs = self._process_args(*args, **kwargs)
#     813         self._process_levels()
#     814
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/matplotlib/contour.py in _process_args(self, corner_mask, *args, **kwargs)
#    1444             self._corner_mask = corner_mask
#    1445
# -> 1446             x, y, z = self._contour_args(args, kwargs)
#    1447
#    1448             _mask = ma.getmask(z)
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1483             args = args[1:]
#    1484         elif Nargs <= 4:
# -> 1485             x, y, z = self._check_xyz(args[:3], kwargs)
#    1486             args = args[3:]
#    1487         else:
#
# ~/anaconda3/envs/joicy/lib/python3.9/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1511
#    1512         if z.ndim != 2:
# -> 1513             raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1514         if z.shape[0] < 2 or z.shape[1] < 2:
#    1515             raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#
# TypeError: Input z must be 2D, not 3D
